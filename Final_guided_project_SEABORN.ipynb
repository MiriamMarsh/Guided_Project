# %% [markdown]
# Miriam Marsh - Guided Project

# %% [markdown]
# In this Guided Project we will be analyzing the Resort and City Hotels using Data Visualization Charts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import guided_project_functions as gpf

# %%
df = pd.read_csv("hotel_bookings.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We see above lots of information for each column above. I see at a glance for the stays in weekend nights the mean and 50% does look accurate. The average is 1 night per stay for the weekend nights.

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# ...

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().value_counts
# Out:
# <bound method DataFrame.value_counts of         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# We can see clearly above which categories have Null Values. I will be taking care of the null Values below.

# %%
df.company.value_counts()
# Out:
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 104.0      1
# 531.0      1
# 160.0      1
# 413.0      1
# 386.0      1
# Name: company, Length: 352, dtype: int64

# %%
df.agent.value_counts()
# Out:
# 9.0      31961
# 240.0    13922
# 1.0       7191
# 14.0      3640
# 7.0       3539
#          ...
# 289.0        1
# 432.0        1
# 265.0        1
# 93.0         1
# 304.0        1
# Name: agent, Length: 333, dtype: int64

# %%
df.agent.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 119390 entries, 0 to 119389
# Series name: agent
# Non-Null Count   Dtype
# --------------   -----
# 103050 non-null  float64
# dtypes: float64(1)
# memory usage: 932.9 KB

# %%
df.agent.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           NaN
# 1           NaN
# 2           NaN
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# I noticed there are null values in 4 columns. The Agent and Company column have the most,  however they do not look like such important columns. I will be deleting those 2 columns below.
# The Country and children's columns have null values aswell.
# For the children's column; I switched the nulls to zero. There were only 4.
# For the  Column; I didn't want to loose the data completely since there were 488 null values. I therefor changed the nulls to other.

# %%
df.hotel.value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %% [markdown]
# We see that the City Hotel is almost double in popularity over the Resort Hotel. Let's analyze further.

# %%
df["children"] = df["children"].fillna(0)

# %% [markdown]
# I changed the nulls to zero's for the children's column.

# %%
df["children"].isnull().sum()
# Out:
# 0

# %%
df["country"].isnull().sum()
# Out:
# 488

# %% [markdown]
# I changed the nulls to other for the Country column.

# %%
df["country"] = df["country"].fillna("other")

# %%
df["country"].isnull().sum()
# Out:
# 0

# %%
df = df.drop(columns = 'agent')

# %%
df = df.drop(columns = 'company')

# %%
df = df.drop(columns = 'required_car_parking_spaces')

# %% [markdown]
# I dropped the above 3 columns above as they are not needed for our analysis.

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date'],
#       dtype='object')

# %%
# I rechecked to make sure that all 3 columns which I removed were successfully removed.

# %%
df["market_segment"].describe()
# Out:
# count        119390
# unique            8
# top       Online TA
# freq          56477
# Name: market_segment, dtype: object

# %%
city = df[(df['hotel'] == "City Hotel")]

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79330 entries, 40060 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           79330 non-null  object
#  1   is_canceled                     79330 non-null  int64
#  2   lead_time                       79330 non-null  int64
#  3   arrival_date_year               79330 non-null  int64
#  4   arrival_date_month              79330 non-null  object
#  5   arrival_date_week_number        79330 non-null  int64
#  6   arrival_date_day_of_month       79330 non-null  int64
#  7   stays_in_weekend_nights         79330 non-null  int64
#  8   stays_in_week_nights            79330 non-null  int64
#  9   adults                          79330 non-null  int64
#  10  children                        79330 non-null  float64
#  11  babies                          79330 non-null  int64
# ...

# %%
resort = df[(df['hotel'] == "Resort Hotel")]

# %% [markdown]
# I divided the data frame into 2 separate data frames for the 2 different types of hotels which we will be analyzing. One data frame I called city and the other is called resort.

# %%
resort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40060 entries, 0 to 40059
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           40060 non-null  object
#  1   is_canceled                     40060 non-null  int64
#  2   lead_time                       40060 non-null  int64
#  3   arrival_date_year               40060 non-null  int64
#  4   arrival_date_month              40060 non-null  object
#  5   arrival_date_week_number        40060 non-null  int64
#  6   arrival_date_day_of_month       40060 non-null  int64
#  7   stays_in_weekend_nights         40060 non-null  int64
#  8   stays_in_week_nights            40060 non-null  int64
#  9   adults                          40060 non-null  int64
#  10  children                        40060 non-null  float64
#  11  babies                          40060 non-null  int64
# ...

# %%
sns.catplot(data=df, hue="hotel", x="is_canceled", kind='count')
plt.suptitle("Hotel Vs. City Reservation Cancelations")
plt.show(1)

# %% [markdown]
# We see from the above chart that the Resort Hotel does have less cancelations in comparison to the City Hotel. It looks like the Resort hotel has about 1/3 of the amount of cancelations as the City Hotel. Even with keeping in mind that the City hotel does have double as many customers, the number of cancelations are still much lower for the Resort.

# %%
sns.catplot(data=df, hue="hotel", x="is_repeated_guest", kind='count')
plt.suptitle("Hotels showing repeated guest")
plt.show()

# %% [markdown]
# We see clearly from the above chart that the the Resort and City Hotel both have about the same amount of Cancelations. However, the City Hotel really has much more customers than the Resort Hotel. We therefor can say that the resort Hotel does have more repeat customers than the City Hotel. Let's do some further analyzing.

# %%
#plt.subplot(1,3,1)
#sns.catplot(data=df, hue="hotel", x="adults", kind='count')
#plt.subplot(1,3,2)
#sns.catplot(data=df, hue="hotel", x="babies", kind='count')
#plt.subplot(1,3,3)
sns.catplot(data=df,  x="children", kind='count', col="hotel")
plt.suptitle("Number of Childrens stays at the hotel")
sns.catplot(data=df,  x="babies", kind='count', col="hotel")
plt.suptitle("Number of Babies at the hotel")
plt.show(1)

# %% [markdown]
# Both the city and the resort hotel had very few children and babies staying at the hotel. However in comparison to the number of guests staying at the hotel the Resort again did have more children and babies over the city.

# %%
sns.catplot(x='hotel',hue='arrival_date_month',data=df,kind='count')
plt.show(1)

# %% [markdown]
# The above chart shows the change in monthly and season patterns at both hotels. I would say the changes are both relatively very similar at both hotels. They both have a nice guest increase in the summer months of July and August. For the cold winter months such as November, December and January there is a decrease in stays. The City hotel than increases nicer over the resort hotels for the Fall months of March, April and May.

# %%
sns.catplot(x='hotel',hue="stays_in_week_nights",data=df,kind='count')
plt.suptitle("Resort vs. City Week Night Stays")
plt.show(1)

# %% [markdown]
# In the above catplot chart we can see at a glance the number of week night stays per hotel. City Hotel is definitely much more popular. Let's analyze further.

# %%
sns.catplot(x='hotel',hue='deposit_type',data=df,kind='count')
plt.show(1)

# %% [markdown]
# Checking above to see if I see any patterns in the deposit type. However, I don't see much. I do see that the deposit type does not effect the Resort Hotel's number of stays. Without this chart I might've thought that the deposit type impacted the lower number of guests at the resort. Here I see the opposite though. There were more Non Refundable stays at the city hotel over the Resort. In addition, it looks like the resort hotel even offered a few customers a Refundable stay and still all in all their guest stays are lower than that of the city. Let's analyze further.

# %%
#Skip For Functions 1:
from guided_project_functions import create_catplot
create_catplot('hotel')
plt.show()

# %% [markdown]
# At a glance we see from this Bar chart that the City Hotel had double as many hotel stays compared to the Resort Hotel. Let's analyze further to see if we can find out why.

# %% [markdown]
# #Skip For Functions 1:
# from guided_project_functions import create_catplot
# create_catplot('adults')
# plt.show()

# %%
sns.heatmap(data=city.corr())
plt.suptitle("City Hotel Heat Map")
plt.show()
sns.heatmap(data=resort.corr())
plt.suptitle("Resort Hotel Heat Map")
plt.show()

# %% [markdown]
# I created a heatmat for the 2 types of data frames which I created. The first is a heatmat for the city hotel and second for the resort hotel. In the above you can see all the different columns at a glance in reference to the hotel they stayed at.

# %%
sns.heatmap(data = resort[["stays_in_weekend_nights", "stays_in_week_nights"]].corr())
plt.suptitle("Resort Hotel Heat Map for stays in week/weekends")
plt.show()
sns.heatmap(data = city[["stays_in_weekend_nights", "stays_in_week_nights"]].corr())
plt.suptitle("City Hotel Heat Map for stays in week/weekends")
plt.show()

# %% [markdown]
# I don't feel like I see much from the above 2 heatmap charts. Let's try something else.

# %%
sns.catplot(x='deposit_type', y='is_canceled', data=city, hue = "customer_type")
plt.show()
plt.suptitle("City Hotel customer type in comparison to Deposit Type")
sns.catplot(x='deposit_type', y='is_canceled', data=resort, hue = "customer_type")
plt.suptitle("Resort Hotel customer type in comparison to Deposit Type")
plt.show()

# %% [markdown]
# In the above charts we see that both hotels didn't have any group bookings. I would recommend they reach out more to groups and try to have a sales rep fully in charge of group bookings. This would help increase their number of guests if they cater more to groups. It looks like the Resort Hotel does have more contract customers over the city hotel. I'm still trying to figure out why the city have more customers than the resort.

# %%
sns.displot(df['customer_type'], rug=True, kde=True)
plt.suptitle('Customer Types')
plt.show(1)

# %% [markdown]
# We see again from the above chart that there were no Group stays, very little contract customers and mainly Transient bookings. I would recommend both hotels to focus on trying to increase their contract and group customers.

# %%
sns.violinplot(x='days_in_waiting_list', data=df, y="hotel", kind='count' ,split=True, inner = "quartile")
plt.suptitle ("Days for the waiting list in Resort vs City")
plt.show()

# %% [markdown]
# It seems that there is a slightly larger waiting list for the city hotel vs. the Resort Hotel. The Resort hotel does not look like it has much of a waiting list at all. This does show that the city hotel again is more popular.

# %%
sns.lmplot(data= df, x = "stays_in_weekend_nights", y="stays_in_week_nights", col="hotel")
plt.show()

# %% [markdown]
# It seems that zeros were inserted when bookings were booked for weekends and  when a booking was made for weeknights without the weekend. We'll remove the outliers to help us analyze better.

# %%
from guided_project_functions import create_boxenplot
create_boxenplot("stays_in_week_nights")
plt.suptitle("Stays in week Nights")
plt.show()

# %%
from guided_project_functions import create_boxenplot
create_boxenplot("stays_in_weekend_nights")
plt.suptitle("Stays in Weekend Nights")
plt.show()

# %% [markdown]
# There seems to be many outliers in the above weekend and week night columns as stated above. We will remove any values that are zeros, as well as any numbers above 10. We can also see how the Week Night stays are more popular over Weekend Nights. I would suggest that the hotels discount the weekend nights to help increase their sales.

# %%
df2=df[df["stays_in_weekend_nights"].between(0,6)]
df2
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
sns.boxenplot(x= df2["stays_in_weekend_nights"])
plt.suptitle("Stays in Weekend Nights Updated")
plt.show()

# %% [markdown]
# For the weekend night stays we see that on aveage most guests stayed between 0-2. There were a small amount that stayed up to 4 weekends.

# %%
df2=df[df["stays_in_week_nights"].between(0,10)]
df2
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
sns.boxenplot(x= df2["stays_in_week_nights"])
plt.suptitle("Stays in Week Nights Updated")
plt.show()

# %% [markdown]
# I removed the outliers above for both the weekend and week night columns. I copied over the new info to a new data frame called df2. I than checked over the data frames to make sure the new info looks more accurate which it does. I checked value counts again below.
# We see in the updated Boxenplot above that on average most guests stayed 1-3 nights. There was anice amount that stayed 4-5 nights and there were a few that stayed 6-10. I would recommend the hotel offer some discounts on those that stay more than 5 week nights. We can even offer a free weekend for those that pay for 6 full nights. This will help increase sales and fill up some of our empty weekend rooms.

# %%
print(df2["stays_in_week_nights"].value_counts().sum())
# Out:
# 118988

# %%
print(df2.value_counts().sum())
# Out:
# 118988

# %%
print(df2["is_canceled"].value_counts().sum())
# Out:
# 118988

# %%
print(df["stays_in_week_nights"].value_counts().sum())
# Out:
# 119390

# %% [markdown]
# I checked a random column above in the df2 and df data frame to make sure the outliers were successfully removed from the df2 data frame.

# %%
print(df2["stays_in_weekend_nights"].value_counts())
# Out:
# 0    51998
# 2    33308
# 1    30626
# 4     1760
# 3     1259
# 5       36
# 6        1
# Name: stays_in_weekend_nights, dtype: int64

# %%
print(df2["stays_in_week_nights"].value_counts())
# Out:
# 2     33684
# 1     30310
# 3     22258
# 5     11077
# 4      9563
# 0      7645
# 6      1499
# 10     1036
# 7      1029
# 8       656
# 9       231
# Name: stays_in_week_nights, dtype: int64

# %%
sns.lmplot(data= df2, x = "stays_in_weekend_nights", y="stays_in_week_nights",  col="hotel")
plt.show(1)

# %% [markdown]
# We see from the above chart that the resort hotel changes faster according to the weekend nights in comparison to the city hotel.

# %% [markdown]
# In Conclusion, we noticed many important points along the way. We noticed the difference in season patterns.
# The summer months are definitely much more popular in both hotels.  I did notice a greater increase in the city hotel vs the resort hotel during the summer months. Every winter I would recommend the hotels running some sort of winter promo to increase the stays of winter bookings as well. We also took a look above at the deposit types, guest types and number of weekend stays. I would recommend to the hotels to try to increase their number of group and contract customers. They should try to advertise more to those crowds and offer them discounted group and contract rates. In addition, it looks like the weekend night stays can definitely use a boost in sales. I would recommend running some sort of weekend stay promo and advertising it well for all to enjoy! This will definitely increase the hotels popularity and fill up the empty rooms over the weekends. I still was not able to come to any good conclusion as to why the city hotel is doubly as popular over the resort hotel. I would need to contact the hotel and get more information. The excel data frame they sent me was not enough information for me to come to the conclusion. I would want to know what is their hotel capacity. Where are they located. Maybe they are not in a popular area. How long ago where their rooms renovated. What star hotel are they considered. All these factors will help me be able to analyze further.

# %% [markdown]
# def create_title(x):
# plt.title("resort and city reervations by {}.form)
#
#
# def out func(x,df)')
# create_catplot(x,df)
# title = create_title(x)
# plt.savefig(title + '.png))
