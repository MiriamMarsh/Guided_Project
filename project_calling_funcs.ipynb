# %% [markdown]
# Miriam Marsh - Guided Project

# %% [markdown]
# I added my 2 functions for this project in line 2 and in line 39.
# The rest of my guided project is not correct as this was not my final version!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
import sys

# %%
from projects_funcs import imports
imports("seaborn with inner functions!", "s")
# Out:
# 2023-01-01 10:23:41.157364
# Miriam Marsh
# This is a new project for seaborn with inner functions!
# <function projects_funcs.imports(a, b)>

# %%
df = pd.read_csv("hotel_bookings.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# We see above lots of information for each column with the mean. I see at a glance for the stays in weekend nights the mean and 50% does look accurate. The average is 1 night per stay for the weekend nights.

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# ...

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().value_counts
# Out:
# <bound method DataFrame.value_counts of         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.company.value_counts()
# Out:
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 104.0      1
# 531.0      1
# 160.0      1
# 413.0      1
# 386.0      1
# Name: company, Length: 352, dtype: int64

# %%
df.agent.value_counts()
# Out:
# 9.0      31961
# 240.0    13922
# 1.0       7191
# 14.0      3640
# 7.0       3539
#          ...
# 289.0        1
# 432.0        1
# 265.0        1
# 93.0         1
# 304.0        1
# Name: agent, Length: 333, dtype: int64

# %%
df.agent.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 119390 entries, 0 to 119389
# Series name: agent
# Non-Null Count   Dtype
# --------------   -----
# 103050 non-null  float64
# dtypes: float64(1)
# memory usage: 932.9 KB

# %%
df.agent.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           NaN
# 1           NaN
# 2           NaN
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
## I noticed there are null values in 4 columns. The Agent and company column have the most,  however they do not look like such important columns. There are more null values in the country and children's columns.

# %%
df.hotel.value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df["children"] = df["children"].fillna(0)

# %%
df["children"].isnull().sum()
# Out:
# 0

# %% [markdown]
# For the children's column, I switched the nulls to zero. There were only 4.

# %%
df["country"].isnull().sum()
# Out:
# 488

# %%
df["country"] = df["country"].fillna("other")

# %%
df["country"].isnull().sum()
# Out:
# 0

# %%
df = df.drop(columns = 'agent')

# %%
df = df.drop(columns = 'company')

# %%
df = df.drop(columns = 'required_car_parking_spaces')

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date'],
#       dtype='object')

# %%
# I rechecked to make sure that all 3 columns which I removed were successfully removed.

# %%
df["market_segment"].describe()
# Out:
# count        119390
# unique            8
# top       Online TA
# freq          56477
# Name: market_segment, dtype: object

# %%
city = df[(df['hotel'] == "City Hotel")]

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79330 entries, 40060 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           79330 non-null  object
#  1   is_canceled                     79330 non-null  int64
#  2   lead_time                       79330 non-null  int64
#  3   arrival_date_year               79330 non-null  int64
#  4   arrival_date_month              79330 non-null  object
#  5   arrival_date_week_number        79330 non-null  int64
#  6   arrival_date_day_of_month       79330 non-null  int64
#  7   stays_in_weekend_nights         79330 non-null  int64
#  8   stays_in_week_nights            79330 non-null  int64
#  9   adults                          79330 non-null  int64
#  10  children                        79330 non-null  float64
#  11  babies                          79330 non-null  int64
# ...

# %%
resort = df[(df['hotel'] == "Resort Hotel")]

# %% [markdown]
# I divided the data frame into 2 separate data frames for the 2 different types of hotels which we will be analyzing. One is called city and one is called resort.

# %%
resort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40060 entries, 0 to 40059
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           40060 non-null  object
#  1   is_canceled                     40060 non-null  int64
#  2   lead_time                       40060 non-null  int64
#  3   arrival_date_year               40060 non-null  int64
#  4   arrival_date_month              40060 non-null  object
#  5   arrival_date_week_number        40060 non-null  int64
#  6   arrival_date_day_of_month       40060 non-null  int64
#  7   stays_in_weekend_nights         40060 non-null  int64
#  8   stays_in_week_nights            40060 non-null  int64
#  9   adults                          40060 non-null  int64
#  10  children                        40060 non-null  float64
#  11  babies                          40060 non-null  int64
# ...

# %%
sns.catplot(data=df, hue="hotel", x="is_canceled", kind='count')
plt.show(1)

# %%
sns.catplot(data=df, hue="hotel", x="is_repeated_guest", kind='count')
plt.suptitle("Hotels showing repeated guest")
plt.show()

# %% [markdown]
# We see clearly from the above chart that the

# %%
plt.subplot(1,3,1)
sns.catplot(data=df, hue="hotel", x="adults", kind='count')
plt.subplot(1,3,2)
sns.catplot(data=df, hue="hotel", x="babies", kind='count')
plt.subplot(1,3,3)
sns.catplot(data=df, hue="hotel", x="children", kind='count')
plt.show(3)

# %%
sns.catplot(x='hotel',hue='arrival_date_month',data=df,kind='count')
plt.show(1)

# %% [markdown]
# The above chart shows how

# %%
sns.catplot(x='hotel',hue='stays_in_week_nights',data=df,kind='count')
plt.show(1)

# %%
sns.catplot(x='hotel',hue='deposit_type',data=df,kind='count')
plt.show(1)

# %%
from guided_project_functions import create_catplot
create_catplot('hotel')
plt.show()

# %%
from projects_funcs import create_catplot
create_catplot('adults', 'number of adult stays')
plt.show()
# Out:
# This is my catplot chart for number of adult stays

# %%
from guided_project_functions import create_catplot
create_catplot('hotel')

# %%
sns.heatmap(data=df.corr(), cmap="PiYG")
plt.show()

# %%
sns.heatmap(data=city.corr(), cmap="PiYG")
plt.show()

# %%
sns.heatmap(data=resort.corr(), cmap="PiYG")
plt.show()

# %%
sns.heatmap(resort[["stays_in_weekend_nights", "stays_in_week_nights"]].corr())
plt.show()

# %%
sns.heatmap(city[["stays_in_weekend_nights", "stays_in_week_nights"]].corr())
plt.show()

# %%
sns.catplot(x='deposit_type', y='is_canceled', data=city, hue = "customer_type")
plt.show()

# %%
sns.catplot(x='deposit_type', y='is_canceled', data=resort, hue = "customer_type")
plt.show()

# %%
sns.displot(df['customer_type'], rug=True, kde=True)
plt.suptitle('Customer Types')
plt.show(1)

# %%
sns.violinplot(x='days_in_waiting_list', data=df, y="hotel", kind='count' ,split=True, inner = "quartile")
#plt.suptitle ("")
plt.show()

# %%
sns.lmplot(data= df, x = "stays_in_weekend_nights", y="stays_in_week_nights", col="hotel")
plt.show()

# %% [markdown]
# zeros look like thery were interserted when bookings were booked for weekend and same when a booking was made for weeknights without the weekend. We'll remove the outliyers to help us analize better.

# %%
from guided_project_functions import create_boxenplot
create_boxenplot("stays_in_week_nights")
plt.show()

# %%
from guided_project_functions import create_boxenplot
create_boxenplot("stays_in_weekend_nights")
plt.show()

# %% [markdown]
# We will remove any values that are zeros, as well as any numbers above 10.

# %%
df2=df[df["stays_in_weekend_nights"].between(0,6)]
df2
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
sns.boxenplot(x= df2["stays_in_weekend_nights"])
plt.show()

# %%
df2=df[df["stays_in_week_nights"].between(0,10)]
df2
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
sns.boxenplot(x= df2["stays_in_week_nights"])
plt.show()

# %%
print(df2["stays_in_week_nights"].value_counts().sum())
# Out:
# 118988

# %%
print(df2.value_counts().sum())
# Out:
# 118988

# %%
print(df2["is_canceled"].value_counts().sum())
# Out:
# 118988

# %%
print(df["stays_in_week_nights"].value_counts().sum())
# Out:
# 119390

# %%
print(df2["stays_in_weekend_nights"].value_counts())
# Out:
# 0    51998
# 2    33308
# 1    30626
# 4     1760
# 3     1259
# 5       36
# 6        1
# Name: stays_in_weekend_nights, dtype: int64

# %%
sns.lmplot(data= df2, x = "stays_in_weekend_nights", y="stays_in_week_nights",  col="hotel")
plt.show(1)

# %%
For the resort  changes faster according to the weenend nights.
# Out:
#   File "C:\Users\Owner\AppData\Local\Temp\ipykernel_34296\2309195441.py", line 1
#     For the resort  changes faster according to the weenend nights.
#         ^
# SyntaxError: invalid syntax

# %%
print(df2["stays_in_week_nights"].value_counts())
# Out:
# 2     33684
# 1     30310
# 3     22258
# 5     11077
# 4      9563
# 0      7645
# 6      1499
# 10     1036
# 7      1029
# 8       656
# 9       231
# Name: stays_in_week_nights, dtype: int64

# %% [markdown]
# In Conclusion, we noticed many important points along the way. We noticed the difference in season patterns.
# The summer months are definetly much more popular in both hotels. However, I did notice a greater increase in the city hotel vs the resort hotel during the summer months.
